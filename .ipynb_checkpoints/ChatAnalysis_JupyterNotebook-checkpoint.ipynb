# %%
import re
import pandas as pd

# %%
f=open('WhatsApp Chat with TY-MP T3-11.txt','r',encoding='utf-8');

# %%
data=f.read()

# %%
print(data)
# Out:
# 08/08/21, 12:58 pm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 08/08/21, 11:58 am - Teknath Jha created group "Ty-mini Project"
# 08/08/21, 11:58 am - Teknath Jha added you
# 08/08/21, 11:59 am - Teknath Jha: aapne aapne   skills batao (languages you know and also frameworks )
# 08/08/21, 12:01 pm - Sanap Aditya: React ,HTML,CSS ,JS ,Python basics
# 08/08/21, 1:19 pm - Avinash: Coordinates iot, ai,ml modern ka karneki bolte hai
# 08/08/21, 1:20 pm - Avinash: Abhi itna tension mat lo batate ho konsa technology use kr ke baneka
# 08/08/21, 4:11 pm - Avinash: You deleted this message
# 08/08/21, 4:12 pm - Avinash: Form bhardo koi to
# 08/08/21, 4:12 pm - Sanap Aditya: Bol ith mail taka
# 08/08/21, 4:12 pm - Sanap Aditya: mi bharto
# 08/08/21, 4:12 pm - Avinash: Koni tari ekanech bharychay
# 08/08/21, 4:13 pm - Sanap Aditya: ha
# 08/08/21, 4:13 pm - Avinash: Bhato ka mag
# 08/08/21, 4:13 pm - Sanap Aditya: ha mail dalo idhAR
# 08/08/21, 4:14 pm - Avinash: avinash.biradar@walchandsangli.ac.in
# 08/08/21, 4:14 pm - Sanap Aditya: prn pn taka
# 08/08/21, 4:14 pm - Avinash: Teknath.jha@walchandsangli.ac.in prn 33
# 08/08/21, 4:14 pm - Avinash: 77
# 08/08/21, 4:14 pm - Sanap Aditya: T capital a ka
# 08/08/21, 4:15 pm - Avinash: Sry small ahe
# 08/08/21, 4:15 pm - Sanap Aditya: ok
# 08/08/21, 4:15 pm - Sanap Aditya: nakki na
# 08/08/21, 4:15 pm - Avinash: Ha
# 08/08/21, 4:18 pm - Sanap Aditya: naav purn takaych ka
# 08/08/21, 4:21 pm - Teknath Jha: teknath.jha@walchandsangli.ac.in
# 08/08/21, 4:21 pm - Teknath Jha: Teknath Krishna Jha
# 08/08/21, 4:21 pm - Teknath Jha: Prn 33
# 08/08/21, 4:22 pm - Sanap Aditya: 2019BTECS00077
# 08/08/21, 4:22 pm - Sanap Aditya: Avinash Vishnu Biradar
# 08/08/21, 4:22 pm - Sanap Aditya: avinash.biradar@walchandsangli.ac.in
# 08/08/21, 4:22 pm - Sanap Aditya: 2019BTECS00033
# 08/08/21, 4:23 pm - Sanap Aditya: Teknath Krishna Jha
# 08/08/21, 4:23 pm - Sanap Aditya: teknath.jha@walchandsangli.ac.in
# 08/08/21, 4:23 pm - Sanap Aditya: check it
# 08/08/21, 4:24 pm - Sanap Aditya: Idea before forming this team : Worked Before and Good interaction
# 08/08/21, 4:25 pm - Sanap Aditya: Mini Project 1 and 2 Group formation
# Your response has been recorded.
# 08/08/21, 4:34 pm - Avinash: 🙌🙌😁
# 08/08/21, 4:42 pm - Teknath Jha: <Media omitted>
# 08/08/21, 4:43 pm - Sanap Aditya: 🤣🤣🤣
# 08/08/21, 4:44 pm - Teknath Jha: <Media omitted>
# Mere sath Manmath tha.. ham dono ne sath me explore kiye the to easy pada hame. knowledge sharing hoti
# 02/09/21, 9:17 pm - Sanap Aditya: kaun bataya ye
# 02/09/21, 9:19 pm - Sanap Aditya: Woh Blog wale idea mein Harry ka video dekh lo react ke liye
# 03/09/21, 9:10 am - Avinash: Aur ek idea hai pr advance hai cpp to python language convertor bana sakte hai
# 03/09/21, 9:10 am - Avinash: Kya
# 03/09/21, 9:10 am - Avinash: ?
# 03/09/21, 9:12 am - Teknath Jha: Kyu per
# 03/09/21, 9:13 am - Teknath Jha: Complexity to bad rahi hai yaha pe
# 03/09/21, 9:13 am - Avinash: All common programming languages are Turing complete, which means there’s nothing one programming language does that another can’t. All programming language can achieve the same algorithms, can solve the same problems, and give the same result if their programs are identical. Therefore, it’s completely possible to convert C++ code to Python.
#
# In the real world, however, this isn’t as easy to do. What you’re looking for is a transpiler, which takes a program from one language to another. As Patrick answered in a different response to this question, C++ and Python have significant paradigm differences that went into the language design which affects the ability to port code from one to another. Probably the trickiest part is that Python is a higher level language than C/C++, and doesn’t have the ability to directly address memory like Python does (Patrick touches on this when mentioning memset()/memcpy()). As thus, transpilers typically do their best to bridge the abstraction gap, which typically fails or makes faulty assumptions.
#
# For example, here’s a simple C program, which I then tried transpiling to Python manually
#
# #include <stdio.h>
#
# int main(){
# 	char* a = "Hello world";
# 	printf("%s", a);
# 	return 0
# }
# _
#
# def main():
# 	a = "Hello world"
# 	print(a)
# 	return 0
# The obvious problem with my literal transpiling, for one, is the programs have different outputs. My C program automatically runs main, as a feature of the C language, while my Python just has a function declaration which is never called. I suppose a smart transpiler will call the function, or use a class with an __init__ function, but then it wouldn’t be a literal transpiling anymore. You can also run into more issues with type calling, memory access issues, and more, which Patrick explained very well in his own answer.
#
# Hope this helped!
# 03/09/21, 9:14 am - Avinash: sahi hai hard jayega
# 03/09/21, 9:22 am - Teknath Jha: https://codebeautify.org/alleditor/cbeb91a3
# 03/09/21, 9:23 am - Avinash: nahi ho raha
# 03/09/21, 9:27 am - Teknath Jha: aiml ka code kisi ko mila kya ?
# 03/09/21, 9:27 am - Teknath Jha: sol of 15 puzzle problem
# 03/09/21, 9:29 am - Avinash: https://blog.goodaudience.com/solving-8-puzzle-using-a-algorithm-7b509c331288
# 03/09/21, 9:35 am - Teknath Jha: so kinda of u
# 03/09/21, 9:40 am - Avinash: means??
# 03/09/21, 9:40 am - Avinash: https://www.geeksforgeeks.org/check-instance-15-puzzle-solvable/  prerequiste
# 03/09/21, 9:41 am - Sanap Aditya: Thanks bol raha hai woh
# 03/09/21, 9:41 am - Avinash: okok
# 03/09/21, 9:48 am - Teknath Jha: yup
# 03/09/21, 12:04 pm - Sanap Aditya: dalna kya apna
# 03/09/21, 12:05 pm - Avinash: Public mat kr
# 03/09/21, 12:05 pm - Avinash: Re
# 03/09/21, 12:05 pm - Avinash: <Media omitted>
# 03/09/21, 12:05 pm - Sanap Aditya: Ok
# 03/09/21, 12:05 pm - Avinash: <Media omitted>
# 03/09/21, 12:05 pm - Sanap Aditya: are idea fix hai na pr
# Any employee/student should get to know current status of document submitted to institute at their figure tips (mobile app/portal). Also statistical analysis and report has to be generated for administrators periodically	Sender will submit documents…ticket will be issued to him/her ( pprox.. time/days to get completed) Keep track.. Generate unique code(label/tag) … generate logs (date, time, person)… sender can check status ..also if issues are there then auto message/email has to be generated to concerned(sender)..after fulfilling query/issue the system should maintain record of it
# App has to be made available through Play store to customers.
# 	WCE faculty/ Staff/ Students- HoDs- Office concerned Clerks   Finance Officer (if related to money) - Registrar--  Accounts Officer-- Director	Responsive web portal and mobile app, SMS & Email notifications/alerts, IoT (sensors, barcode, RFID, scanner, arduino etc), Cloud platform, docker/container, authentication, auto signs, Ticket granting system, access control
# 07/09/21, 6:22 pm - Teknath Jha: //
# 07/09/21, 6:22 pm - Teknath Jha: Pranita Bhosale and Team 	WCE Document tracking and reporting system: Bills, Requisitions, Reports, Proposals.
#
# Any employee/student should get to know current status of document submitted to institute at their figure tips (mobile app/portal). Also statistical analysis and report has to be generated for administrators periodically	Sender will submit documents…ticket will be issued to him/her ( pprox.. time/days to get completed) Keep track.. Generate unique code(label/tag) … generate logs (date, time, person)… sender can check status ..also if issues are there then auto message/email has to be generated to concerned(sender)..after fulfilling query/issue the system should maintain record of it
# App has to be made available through Play store to customers.
# 	WCE faculty/ Staff/ Students- HoDs- Office concerned Clerks   Finance Officer (if related to money) - Registrar--  Accounts Officer-- Director	Responsive web portal and mobile app, SMS & Email notifications/alerts, IoT (sensors, barcode, RFID, scanner, arduino etc), Cloud platform, docker/container, authentication, auto signs, Ticket granting system, access control
# 08/09/21, 5:09 pm - Teknath Jha: <Media omitted>
# 08/09/21, 5:09 pm - Teknath Jha: <Media omitted>
# 08/09/21, 5:26 pm - Teknath Jha: https://www.gatevidyalay.com/travelling-salesman-problem-using-branch-and-bound-approach/
# 08/09/21, 10:48 pm - Avinash: https://8worx.blogspot.com/2020/09/document-tracking-system-v-20.html
# 08/09/21, 10:48 pm - Avinash: reference
# 08/09/21, 10:49 pm - Teknath Jha: Abstract :
# 08/09/21, 10:49 pm - Teknath Jha: Students have been facing problems in tracking their documents for
# verification at institute level and sometime they also missed deadlines
# of availing scholarships .
# We develop a website "Doc Tracker" which will notify student to track their
# documents direct via our website, they will be notified via emails on each
# successive stages of document .
# This website will help  to short out the communication between authority and
# student . Student will not miss their scholarship.
# College staff will be able to direct contact to student to get work done.
# 08/09/21, 10:49 pm - Teknath Jha: 😍
# 09/09/21, 7:01 am - Teknath Jha: This message was deleted
# 09/09/21, 7:01 am - Teknath Jha: baki complete karo  ye incomplete hai
# 09/09/21, 7:22 am - Teknath Jha: <Media omitted>
# 09/09/21, 7:23 am - Teknath Jha: Methodology and flowchart baki hai
# 09/09/21, 7:23 am - Teknath Jha: flowchart add karde avi
# 09/09/21, 7:23 am - Teknath Jha: methodology kisi ko pata haai to add kardo
# 09/09/21, 3:08 pm - Sanap Aditya: methodology matlab agile jaisa na
# 09/09/21, 3:58 pm - Teknath Jha: are huwa kya sab log free
# 09/09/21, 3:58 pm - Teknath Jha: meet pe aao phir
# 09/09/21, 5:22 pm - Teknath Jha: https://www.youtube.com/watch?v=gSQXq2_j-mw
# 10/09/21, 10:52 am - Teknath Jha: Delete ka kuch nahi rakh
# 10/09/21, 10:53 am - Sanap Aditya: OK
# 10/09/21, 10:53 am - Teknath Jha: Vo privacy me hojae ga
# 10/09/21, 10:53 am - Sanap Aditya: Pr aapn woh invalid doc bhi data base mai dalenge na
# 10/09/21, 10:53 am - Sanap Aditya: toh woh delete karna hoga
# 10/09/21, 10:53 am - Teknath Jha: Nahi uska rahede
# 10/09/21, 10:54 am - Sanap Aditya: ye karu kya
# 10/09/21, 10:54 am - Teknath Jha: Document student hai so vahi delete kare ga ya update kare ga
# 10/09/21, 10:54 am - Teknath Jha: Nahi
# 10/09/21, 10:55 am - Teknath Jha: 🛑
# 10/09/21, 11:09 am - Sanap Aditya: are desk 2 ko rejection nahi denge na
# 10/09/21, 11:18 am - Sanap Aditya: <Media omitted>
# 10/09/21, 11:18 am - Sanap Aditya: DEkho re
# 10/09/21, 11:23 am - Avinash: 👍
# 10/09/21, 11:23 am - Sanap Aditya: koi changes
# 10/09/21, 11:23 am - Avinash: Nhi nhi
# 10/09/21, 11:23 am - Sanap Aditya: 👍👍
# 10/09/21, 11:50 am - Teknath Jha: <Media omitted>
# 10/09/21, 11:50 am - Teknath Jha: <Media omitted>
# 10/09/21, 11:50 am - Sanap Aditya: 👍👍
# 10/09/21, 7:30 pm - Teknath Jha: https://cses.fi/problemset/task/1682/
# 10/09/21, 7:30 pm - Teknath Jha: kisi ko aata hai kya ye  ?
# 10/09/21, 9:10 pm - Avinash: just check whether there any node which has 0 outgoing edge or o incoming edge then not possible
# 10/09/21, 9:11 pm - Sanap Aditya: 👍👍👍
# 10/09/21, 9:11 pm - Sanap Aditya: MEthodology hui kya
# 10/09/21, 9:11 pm - Avinash: kr raha hu
# 10/09/21, 9:11 pm - Sanap Aditya: <Media omitted>
# 10/09/21, 9:12 pm - Sanap Aditya: <Media omitted>
# 10/09/21, 10:26 pm - Teknath Jha: I did but there's something more  requirements failed  connection we've to print
# 10/09/21, 10:37 pm - Avinash: You deleted this message
# 10/09/21, 10:38 pm - Avinash: You deleted this message
# 10/09/21, 10:46 pm - Avinash: and also one more condition if there is cycle present then also won't possible
# 10/09/21, 10:46 pm - Avinash: cycle with no of nodes less than all nodes
# 11/09/21, 9:14 am - Avinash: <Media omitted>
# 11/09/21, 10:09 am - Teknath Jha: send in  downloadable format
# 11/09/21, 10:25 am - Avinash: <Media omitted>
# 11/09/21, 10:25 am - Avinash: is it ok ??
# 11/09/21, 10:26 am - Avinash: please send here the updated ppt
# 11/09/21, 10:27 am - Teknath Jha: <Media omitted>
# 11/09/21, 10:27 am - Avinash: yai dala kya
# 11/09/21, 10:27 am - Avinash: usme
# 11/09/21, 10:27 am - Teknath Jha: plz add your work in respective  page
# 11/09/21, 10:27 am - Teknath Jha: nope
# 11/09/21, 10:27 am - Teknath Jha: its hard to extract .drawio file
# 11/09/21, 10:34 am - Avinash: <Media omitted>
# 11/09/21, 10:34 am - Avinash: done from my side my part
# 11/09/21, 10:39 am - Teknath Jha: send  here finnal one from @919421243938
# 11/09/21, 10:40 am - Sanap Aditya: Ky paathavu
# 11/09/21, 10:40 am - Teknath Jha: merge  you  image into this ppt
# 11/09/21, 10:41 am - Sanap Aditya: So image merge karu na
# 11/09/21, 10:41 am - Teknath Jha: your*
# 11/09/21, 10:41 am - Sanap Aditya: Ohh
# 11/09/21, 10:41 am - Teknath Jha: <Media omitted>
# 11/09/21, 10:44 am - Sanap Aditya: are woh vertical fit nahi ho rahi
# 11/09/21, 10:45 am - Sanap Aditya: Ye page ka layout change nahi karna kya
# 11/09/21, 10:45 am - Avinash: download in png format and try again
# 11/09/21, 10:45 am - Sanap Aditya: .
# 11/09/21, 10:46 am - Avinash: <Media omitted>
# 11/09/21, 10:46 am - Sanap Aditya: aisa hai
# 11/09/21, 10:46 am - Sanap Aditya: <Media omitted>
# 11/09/21, 10:46 am - Avinash: like this
# 11/09/21, 10:47 am - Avinash: 👍
# 11/09/21, 10:47 am - Avinash: reduce flow chart title size
# 11/09/21, 10:47 am - Sanap Aditya: OK
# 11/09/21, 10:47 am - Sanap Aditya: But it is fixed na
# 11/09/21, 10:47 am - Sanap Aditya: matlab woh specify kiya hai
# 11/09/21, 10:47 am - Sanap Aditya: font and size
# 11/09/21, 10:48 am - Avinash: just delete the instructions and resize
# 11/09/21, 10:48 am - Sanap Aditya: Aur jo diagrams ke liye font size hai uska kya
# 11/09/21, 10:49 am - Sanap Aditya: woh to image mai reduce ho gaya na
# 11/09/21, 10:49 am - Avinash: janede jo sahi lage vo kr flowachart ko kabhi size,alignment  rahta kya
# 11/09/21, 10:49 am - Avinash: unhone copy paste kiya hai
# 11/09/21, 10:49 am - Avinash: dekha nahi khuch
# 11/09/21, 10:50 am - Sanap Aditya: Ok
# 11/09/21, 10:50 am - Sanap Aditya: <Media omitted>
# 11/09/21, 10:51 am - Sanap Aditya: Dekho re
# 11/09/21, 10:53 am - Sanap Aditya: Avinash tu pn image merge keliy na
# 11/09/21, 10:56 am - Teknath Jha: <Media omitted>
# 11/09/21, 10:56 am - Teknath Jha: final one
# 11/09/21, 10:58 am - Avinash: <Media omitted>
# 11/09/21, 10:58 am - Sanap Aditya: Are ky hai re
# 11/09/21, 10:58 am - Sanap Aditya: Ek baar hi change karo na
# 11/09/21, 10:59 am - Avinash: final.
# 11/09/21, 10:59 am - Teknath Jha: Why u don't remove those header suggestions tag font roman n linespace 1 n fontsize I ve just correct those 🆗
# 11/09/21, 10:59 am - Teknath Jha: 😂
# 11/09/21, 11:00 am - Sanap Aditya: OK
# 11/09/21, 11:00 am - Avinash: <Media omitted>
# 11/09/21, 11:01 am - Sanap Aditya: <Media omitted>
# 11/09/21, 11:01 am - Avinash: one thing i have dought in methdology
# 11/09/21, 11:01 am - Avinash: i think what i have created is not methdology
# 11/09/21, 11:01 am - Sanap Aditya: <Media omitted>
# 11/09/21, 11:02 am - Avinash: methdolgy means steps of building the project like design ,coding..
# 11/09/21, 11:02 am - Avinash: like that please check ones...
# 11/09/21, 2:07 pm - Avinash: Tumhra nhi hua kya
# 11/09/21, 2:07 pm - Avinash: Pl ka
# 11/09/21, 2:07 pm - Teknath Jha: pl nahi huywa
# 11/09/21, 2:07 pm - Avinash: Kha pe submit ok rna hai
# 11/09/21, 2:07 pm - Avinash: Krna*
# 11/09/21, 2:07 pm - Teknath Jha: kal hai
# 11/09/21, 2:08 pm - Teknath Jha: sir ne boila hai vo check kare ga
# 11/09/21, 2:08 pm - Teknath Jha: system pe
# 11/09/21, 2:08 pm - Avinash: Ok
# 11/09/21, 2:08 pm - Avinash: Link vgera khuch aya nhi na
# 11/09/21, 2:08 pm - Teknath Jha: nope
# 11/09/21, 2:08 pm - Avinash: Submit krne ka
# 11/09/21, 2:08 pm - Avinash: 🙏
# 11/09/21, 2:09 pm - Sanap Aditya: Avinash tereko kuch kaam hai kya
# 11/09/21, 2:09 pm - Avinash: N hi
# 11/09/21, 2:10 pm - Sanap Aditya: Nahi to aapn dono meet leke woh method ka krte
# 11/09/21, 2:10 pm - Sanap Aditya: abhi
# 11/09/21, 2:10 pm - Avinash: 5 bhe kte
# 11/09/21, 2:10 pm - Avinash: Krte
# 11/09/21, 2:10 pm - Sanap Aditya: teknath mera PL3 tere saath hai
# 11/09/21, 2:11 pm - Teknath Jha: kya kab hgai tera
# 11/09/21, 2:11 pm - Avinash: Aaj to hoga nhi na
# 11/09/21, 2:11 pm - Sanap Aditya: kal link bhejna
# 11/09/21, 2:11 pm - Sanap Aditya: ?
# 11/09/21, 2:11 pm - Avinash: 5 bje
# 11/09/21, 2:11 pm - Sanap Aditya: nahi PL3 kal hai t6 ka
# 11/09/21, 2:11 pm - Avinash: Are pl3 nhi mp
# 11/09/21, 2:12 pm - Avinash: Bol raha hu mai
# 11/09/21, 2:12 pm - Sanap Aditya: <Media omitted>
# 11/09/21, 2:13 pm - Sanap Aditya: are avinash kar letee
# 11/09/21, 2:13 pm - Sanap Aditya: baad me lag jayenge
# 11/09/21, 2:13 pm - Teknath Jha: nai nai ye sab time waste hai
# 11/09/21, 2:13 pm - Teknath Jha: <Media omitted>
# 11/09/21, 2:14 pm - Sanap Aditya: Bada hoja bhai
# 11/09/21, 2:18 pm - Avinash: Thik hai aa
# 11/09/21, 2:18 pm - Sanap Aditya: @917219578500  kidhar hai
# 11/09/21, 2:19 pm - Avinash: .
# 11/09/21, 2:50 pm - Avinash: Requirement Gathering and Analysis
# 11/09/21, 2:50 pm - Avinash: to determine the document management
# procedures and the problems encountered in the university.
# These interviews also aim to find out the flow of the
# documents throughout the process of receiving, searching, and
# monitoring and through the filing procedures. Along with the
# interview, pre-test questionnaires are given out to the end
# users such as the deans and the secretaries to evaluate the
# system requirements (See appendix F for the pre-test
# questionnaire).
# 11/09/21, 2:50 pm - Avinash: read
# 11/09/21, 2:50 pm - Avinash: aye nhi dal ne vala
# 11/09/21, 2:51 pm - Avinash: lekin requirmnet analysis bhi jaruri hai na
# 11/09/21, 2:51 pm - Avinash: ye dikhnekeliye
# 11/09/21, 2:52 pm - Teknath Jha: ok
# 12/09/21, 7:23 pm - Teknath Jha: Sir ko bhej diya kab ka
# 12/09/21, 7:51 pm - Sanap Aditya: Kya re
# 13/09/21, 10:08 am - Teknath Jha: <Media omitted>
# 13/09/21, 10:08 am - Teknath Jha: Yahi baki tha aab
# 13/09/21, 10:08 am - Teknath Jha: <Media omitted>
# 13/09/21, 10:08 am - Teknath Jha: <Media omitted>
# 13/09/21, 10:10 am - Teknath Jha: Exam ka link bhejo koi to
# 13/09/21, 10:16 am - Avinash: Dear Students,
# To appear for the exam kindly use the below link:-
# http://wcoe.unionline.in
#
# Checklist/Requirement :
# 1. Mobile phone / laptop / PC with working front camera as Web cam.
# 2. Make sure your using updated browser such as (Chrome or Mozilla Firefox)
# -Username is your enrollment no.
# -Password is your mobile number
# - Upload your Admit Card/recent passport size photo for Face Recognition process.
# - Keep the scanned image ready for uploading during the authentication process. Store it on desktop or File Manager if using Mobile Phone.
# - The system will match your Photo along with your Hall ticket.
# -Must have an active internet connection.
# -Also make sure your mobile or laptop is fully charged.
# -Keep required stationery handy with you (pencil, pen, rough sheet etc.)
# - Make sure your browser is allowed to access Camera to avoid Camera error.
#
# Note- Do not write answers in the empty box given below the question your answers won't be considered.
# Instead write on a piece of paper and upload answers using the select file button
# 13/09/21, 10:54 am - Teknath Jha: <Media omitted>
# 13/09/21, 10:55 am - Teknath Jha: Exam huwa to aazo
# 13/09/21, 10:55 am - Teknath Jha: Hume suru se suru karna hai
# 13/09/21, 10:56 am - Sanap Aditya: ...
# 13/09/21, 10:56 am - Teknath Jha: Customers are WCE faculty and students...
# 13/09/21, 10:56 am - Teknath Jha: There may be 3-4 desks a file/document may travel ...we need to understand source sender ..to destination (To whom ) and intermediate desks till work is not done sequences...So need to consider use cases ...for eg "a faculty submits document through HoD to Director for sanction of bills (some work done)" ...then sequences are as 1. faculty submits to HoD...2. HoD signs recommends and sent it through a peon book to Office inward section ...it is acknowledged in the peon book as received with timestamp (date/time )...then it goes to registrar ...second ack needed here with timestamp ..then he assigns it to concerned section clerk ..third ack needed here with timestamp...then when that work done it goes to registrar ...fourth ack needed ..then registrar submits it to director using a book entry...fifth ack needed...then when done from director again it comes to registrar ...sixth ack needed and then it goes to Accounts Officer....seventh ack required ...then to cashier ...eighth ack needed ...and finally notification is required for sender like SMS that the work is done
# 13/09/21, 10:56 am - Teknath Jha: 🥲
# 13/09/21, 11:01 am - Sanap Aditya: mai bola tha ki sir ko puchlo ki kaisa chahiye
# 13/09/21, 11:02 am - Sanap Aditya: <Media omitted>
# 13/09/21, 11:03 am - Sanap Aditya: Ab ek kaam karte
# 13/09/21, 11:04 am - Sanap Aditya: Sir ke saath ek meet rakhte
# 13/09/21, 11:04 am - Sanap Aditya: aur sir ko kya chahiye aur document validation college mai kaise work karta ye puchte
# 13/09/21, 11:05 am - Teknath Jha: Aditya tu leader hai
# 13/09/21, 11:05 am - Sanap Aditya: Nahi be
# 13/09/21, 11:05 am - Teknath Jha: Jo karna hai kar
# 13/09/21, 11:05 am - Teknath Jha: Meet sab
# 10/03/22, 1:39 pm - Teknath Jha: https://shop.gadgetsnow.com/mouse/dell-ms116-optical-mouse-black-/10432/p_G208246?gclid=Cj0KCQiA64GRBhCZARIsAHOLriKurA29MEae-XIzUr5Ih3eu9Vesxg10WbuGGxVbyd4xDd8VZvjvrNsaAl2QEALw_wcB
# 10/03/22, 2:49 pm - Avinash: https://data-flair.training/blogs/machine-learning-project-ideas/
# 12/03/22, 2:30 pm - Sanap Aditya: https://github.com/Arshad221b/Sign-Language-Recognition
# 12/03/22, 2:36 pm - Sanap Aditya: https://github.com/anik8gupta/Toxic_Speech_Classification
# 12/03/22, 2:50 pm - Sanap Aditya: https://github.com/emilwallner/Screenshot-to-code
# 15/03/22, 1:23 pm - Sanap Aditya: .
# 15/03/22, 1:24 pm - Teknath Jha: nice
# 15/03/22, 1:24 pm - Teknath Jha: ppt bano aab
# 15/03/22, 1:24 pm - Sanap Aditya: <Media omitted>
# 15/03/22, 2:10 pm - Sanap Aditya: Neural netwok hai to methodology kya dalu
# 15/03/22, 2:11 pm - Avinash: konsa kr rha hai
# 15/03/22, 2:11 pm - Sanap Aditya: ss to code
# 15/03/22, 2:12 pm - Avinash: ohk'
# 15/03/22, 2:58 pm - Sanap Aditya: <Media omitted>
# 15/03/22, 2:59 pm - Sanap Aditya: Dekhlo
# 15/03/22, 2:59 pm - Sanap Aditya: aur diagrams daldo
# 15/03/22, 3:00 pm - Avinash: 👏👏
# 15/03/22, 3:02 pm - Sanap Aditya: <Media omitted>
# 15/03/22, 3:03 pm - Teknath Jha: ✌️
# 15/03/22, 3:05 pm - Avinash: <Media omitted>
# 17/03/22, 7:15 pm - Teknath Jha: <Media omitted>
# 19/03/22, 12:21 am - Teknath Jha: <Media omitted>
# 19/03/22, 12:22 am - Teknath Jha: Currently in schools teachers perform manual work to prepare and track students learning’s outcome through report cards. This is the standard procedure done manually throughout the country. Often it is observed that students are also good in co-curricular activities and being good in academics is not the only way ahead. In current situation it is not possible for a teacher to pay attention to every student and find out the best in a child. Hence there is a need to develop solutions to track all activities of a student including the academic progress in real-time. Innovation in this domain will be appreciated to develop systems which automatically reads the students progress and generates feedback also is a good way to proceed.

# %%
pattern='\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s(AM|PM|am|pm)?\s-\s'

# %%
messages = re.split(pattern, data)[1:]
messages
# Out:
# ['pm',
#  'Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'am',
#  'Teknath Jha created group "Ty-mini Project"\n',
#  'am',
#  'Teknath Jha added you\n',
#  'am',
#  'Teknath Jha: aapne aapne   skills batao (languages you know and also frameworks )\n',
#  'pm',
#  'Sanap Aditya: React ,HTML,CSS ,JS ,Python basics\n',
#  'pm',
#  'Avinash: Coordinates iot, ai,ml modern ka karneki bolte hai\n',
#  'pm',
#  'Avinash: Abhi itna tension mat lo batate ho konsa technology use kr ke baneka\n',
#  'pm',
#  'Avinash: You deleted this message\n',
#  'pm',
#  'Avinash: Form bhardo koi to\n',
#  'pm',
#  'Sanap Aditya: Bol ith mail taka\n',
#  'pm',
#  'Sanap Aditya: mi bharto\n',
#  'pm',
#  'Avinash: Koni tari ekanech bharychay\n',
#  'pm',
#  'Sanap Aditya: ha\n',
#  'pm',
#  'Avinash: Bhato ka mag\n',
#  'pm',
#  'Sanap Aditya: ha mail dalo idhAR\n',
#  'pm',
#  'Avinash: avinash.biradar@walchandsangli.ac.in\n',
#  'pm',
#  'Sanap Aditya: prn pn taka\n',
#  'pm',
#  'Avinash: Teknath.jha@walchandsangli.ac.in prn 33\n',
#  'pm',
#  'Avinash: 77\n',
#  'pm',
#  'Sanap Aditya: T capital a ka\n',
#  'pm',
#  'Avinash: Sry small ahe\n',
#  'pm',
#  'Sanap Aditya: ok\n',
#  'pm',
#  'Sanap Aditya: nakki na\n',
#  'pm',
#  'Avinash: Ha\n',
#  'pm',
#  'Sanap Aditya: naav purn takaych ka\n',
#  'pm',
#  'Teknath Jha: teknath.jha@walchandsangli.ac.in\n',
#  'pm',
#  'Teknath Jha: Teknath Krishna Jha\n',
#  'pm',
#  'Teknath Jha: Prn 33\n',
#  'pm',
#  'Sanap Aditya: 2019BTECS00077\n',
#  'pm',
#  'Sanap Aditya: Avinash Vishnu Biradar\n',
#  'pm',
#  'Sanap Aditya: avinash.biradar@walchandsangli.ac.in\n',
#  'pm',
#  'Sanap Aditya: 2019BTECS00033\n',
#  'pm',
#  'Sanap Aditya: Teknath Krishna Jha\n',
#  'pm',
#  'Sanap Aditya: teknath.jha@walchandsangli.ac.in\n',
#  'pm',
#  'Sanap Aditya: check it\n',
#  'pm',
#  'Sanap Aditya: Idea before forming this team : Worked Before and Good interaction\n',
#  'pm',
#  'Sanap Aditya: Mini Project 1 and 2 Group formation\nYour response has been recorded.\n',
#  'pm',
#  'Avinash: 🙌🙌😁\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: 🤣🤣🤣\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Teknath Jha: Anil surve sir\n',
#  'pm',
#  'Teknath Jha: For both mini project\n',
#  'pm',
#  'Avinash: Ha ab technology batayenge\n',
#  'pm',
#  'Teknath Jha changed the subject from "Ty-mini Project" to "Ty-mini Project T7 grp-11"\n',
#  'pm',
#  'Sanap Aditya: T3 hai na apna\n',
#  'pm',
#  'Teknath Jha changed the subject from "Ty-mini Project T7 grp-11" to "Ty-mini Project T3 grp-11"\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: <Media omitted>\n',
#  'pm',
#  'Avinash: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya changed the subject from "Ty-mini Project T3 grp-11" to "TY-MP T3-11"\n',
#  'pm',
#  'Sanap Aditya: woh DAA ka kya karna hai\n',
#  'pm',
#  'Avinash: Karna hai assignment\n',
#  'pm',
#  'Sanap Aditya: code karaychay ka\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: bata na sahi se\n',
#  'pm',
#  'Sanap Aditya: https://timesofindia.indiatimes.com/india/web-portal-to-donate-money-to-capf-martyrs-launched-by-govt/articleshow/58096165.cms\n',
#  'pm',
#  'Sanap Aditya: Akshay Kumars website\n',
#  'pm',
#  'Sanap Aditya: Info\n',
#  'pm',
#  'Teknath Jha: An to aiml se he kuch Karna hai\n',
#  'pm',
#  'Teknath Jha: Sir ka msg dekha\n',
#  'pm',
#  'Teknath Jha: https://www.analyticsinsight.net/5-artificial-intelligence-technologies-are-upgrading-the-future-of-ai/\n',
#  'am',
#  'Teknath Jha: <Media omitted>\n',
#  'am',
#  'Avinash: 👍\n',
#  'pm',
#  'Sanap Aditya: ye karna hai kya\n',
#  'pm',
#  'Teknath Jha: Share ur opinions too\n',
#  'pm',
#  'Sanap Aditya: Web dev mein koi problem hai kya\n',
#  'pm',
#  'Teknath Jha: Im asking about topics base idea\n',
#  'pm',
#  'Sanap Aditya: any other idea\n',
#  'pm',
#  'Sanap Aditya: means the army one and this one\n',
#  'am',
#  'Teknath Jha: web scrapping ke bare me padlo thora sa\n',
#  'pm',
#  'Avinash: 3 baje meeting lete aaj\n',
#  'pm',
#  'Avinash: web scrapping ka dekh ke aav\n',
#  'pm',
#  'Avinash: aajao*\n',
#  'pm',
#  'Avinash: .also this\n',
#  'pm',
#  'Avinash: https://meet.google.com/tmk-zsux-hnf\n',
#  'pm',
#  'Teknath Jha: 👍\n',
#  'pm',
#  'Avinash: You deleted this message\n',
#  'pm',
#  'Sanap Aditya: 👍\n',
#  'pm',
#  'Sanap Aditya: meeet me hai kya koi\n',
#  'pm',
#  'Avinash: join\n',
#  'pm',
#  'Avinash: ho teknth\n',
#  'pm',
#  'Teknath Jha: Haa\n',
#  'pm',
#  'Sanap Aditya: ho gayi khatam\n',
#  'pm',
#  'Avinash: meeting ended\n',
#  'pm',
#  'Sanap Aditya: karna hai kya\n',
#  'pm',
#  'Teknath Jha: Are aaona abhi\n',
#  'pm',
#  'Sanap Aditya: thik ye re\n',
#  'pm',
#  'Avinash: aur idea banke aao uske baad lete hai\n',
#  'pm',
#  'Teknath Jha: Ok\n',
#  'pm',
#  'Sanap Aditya: tu aa apn karte baat\n',
#  'pm',
#  'Avinash: aao jaldi\n',
#  'pm',
#  'Teknath Jha: meet.google.com/gkf-cfqd-wrb\n',
#  'pm',
#  'Teknath Jha: any one have idea  for projectt\n',
#  'pm',
#  'Sanap Aditya: Till now no new idea\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Teknath Jha: we want yaar\n',
#  'pm',
#  'Sanap Aditya: Is there idea from Your side\n',
#  'pm',
#  'Teknath Jha: have but not scalable\n',
#  'pm',
#  'Sanap Aditya: Tell us\n',
#  'pm',
#  'Teknath Jha: koi hackathon ka utha lkelte hai\n',
#  'pm',
#  'Teknath Jha: kuch saal pahele ka koi idea hogaa\n',
#  'pm',
#  'Sanap Aditya: matlab\n',
#  'pm',
#  'Teknath Jha: vo\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: Search for ideas in different hackthon conducted\n',
#  'pm',
#  'Sanap Aditya: we will improve them later\n',
#  'am',
#  'Teknath Jha: https://youtu.be/PMmk3BEXhlo\n',
#  'am',
#  'Teknath Jha: <Media omitted>\n',
#  'am',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Avinash: https://meet.google.com/tiv-djou-djs\n',
#  'pm',
#  'Avinash: join immediately\n',
#  'pm',
#  'Avinash: only for 5 min\n',
#  'pm',
#  'Teknath Jha: Google pe seach karte hai aaisa kuch ho raha hai kya\n',
#  'pm',
#  'Teknath Jha: Simple website and Android chodke kuch complex technology use kar.. interview me accha effect padta hai...\n',
#  'pm',
#  'Teknath Jha: Is sem bhi thoda complex technology pe kar...\nFir agle sem me placement preparation ka bhi rahta hai to tab tu easy web ya android kar sakta hai\n',
#  'pm',
#  'Teknath Jha: AR , blockchain, ML , Web Automation , Cloud SaaS\n',
#  'pm',
#  'Teknath Jha: Yeh kuch acche and latest domain hai\n',
#  'pm',
#  'Teknath Jha: Na.. padna padega thoda.. concept easy hai.. implementation me thodi problem jati hai... Internet pe exact code material asani se nahi milta\n',
#  'pm',
#  'Teknath Jha: Par agr tune solidity and thoda basic kar liya to fir baki sab easy hai... Bas starting me thoda hard jata..\n',
#  'pm',
#  'Teknath Jha: Agr sath me koi dost hai.. jo utne hi dedication se karega  jitna tu to easy jayega...\nMere sath Manmath tha.. ham dono ne sath me explore kiye the to easy pada hame. knowledge sharing hoti\n',
#  'pm',
#  'Sanap Aditya: kaun bataya ye\n',
#  'pm',
#  'Sanap Aditya: Woh Blog wale idea mein Harry ka video dekh lo react ke liye\n',
#  'am',
#  'Avinash: Aur ek idea hai pr advance hai cpp to python language convertor bana sakte hai\n',
#  'am',
#  'Avinash: Kya\n',
#  'am',
#  'Avinash: ?\n',
#  'am',
#  'Teknath Jha: Kyu per\n',
#  'am',
#  'Teknath Jha: Complexity to bad rahi hai yaha pe\n',
#  'am',
#  'Avinash: All common programming languages are Turing complete, which means there’s nothing one programming language does that another can’t. All programming language can achieve the same algorithms, can solve the same problems, and give the same result if their programs are identical. Therefore, it’s completely possible to convert C++ code to Python.\n\nIn the real world, however, this isn’t as easy to do. What you’re looking for is a transpiler, which takes a program from one language to another. As Patrick answered in a different response to this question, C++ and Python have significant paradigm differences that went into the language design which affects the ability to port code from one to another. Probably the trickiest part is that Python is a higher level language than C/C++, and doesn’t have the ability to directly address memory like Python does (Patrick touches on this when mentioning memset()/memcpy()). As thus, transpilers typically do their best to bridge the abstraction gap, which typically fails or makes faulty assumptions.\n\nFor example, here’s a simple C program, which I then tried transpiling to Python manually\n\n#include <stdio.h> \n \nint main(){ \n\tchar* a = "Hello world"; \n\tprintf("%s", a); \n\treturn 0 \n} \n_\n\ndef main(): \n\ta = "Hello world" \n\tprint(a) \n\treturn 0 \nThe obvious problem with my literal transpiling, for one, is the programs have different outputs. My C program automatically runs main, as a feature of the C language, while my Python just has a function declaration which is never called. I suppose a smart transpiler will call the function, or use a class with an __init__ function, but then it wouldn’t be a literal transpiling anymore. You can also run into more issues with type calling, memory access issues, and more, which Patrick explained very well in his own answer.\n\nHope this helped!\n',
#  'am',
#  'Avinash: sahi hai hard jayega\n',
#  'am',
#  'Teknath Jha: https://codebeautify.org/alleditor/cbeb91a3\n',
#  'am',
#  'Avinash: nahi ho raha\n',
#  'am',
#  'Teknath Jha: aiml ka code kisi ko mila kya ?\n',
#  'am',
#  'Teknath Jha: sol of 15 puzzle problem\n',
#  'am',
#  'Avinash: https://blog.goodaudience.com/solving-8-puzzle-using-a-algorithm-7b509c331288\n',
#  'am',
#  'Teknath Jha: so kinda of u\n',
#  'am',
#  'Avinash: means??\n',
#  'am',
#  'Avinash: https://www.geeksforgeeks.org/check-instance-15-puzzle-solvable/  prerequiste\n',
#  'am',
#  'Sanap Aditya: Thanks bol raha hai woh\n',
#  'am',
#  'Avinash: okok\n',
#  'am',
#  'Teknath Jha: yup\n',
#  'pm',
#  'Sanap Aditya: dalna kya apna\n',
#  'pm',
#  'Avinash: Public mat kr\n',
#  'pm',
#  'Avinash: Re\n',
#  'pm',
#  'Avinash: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: Ok\n',
#  'pm',
#  'Avinash: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: are idea fix hai na pr\n',
#  'pm',
#  'Avinash: Ha\n',
#  'pm',
#  'Avinash: Info nikal\n',
#  'pm',
#  'Avinash: Mila to\n',
#  'pm',
#  'Sanap Aditya: OK\n',
#  'pm',
#  'Sanap Aditya: aniket kankekar has doing project pon some healthcare problem\n',
#  'pm',
#  'Teknath Jha: ?\n',
#  'pm',
#  'Sanap Aditya: kuch nahi re\n',
#  'pm',
#  'Teknath Jha: blockchain use karke ek network banate ha\n',
#  'pm',
#  'Sanap Aditya: T3 ka grp dekh\n',
#  'pm',
#  'Sanap Aditya: ?\n',
#  'pm',
#  'Teknath Jha: company ke liye\n',
#  'pm',
#  'Teknath Jha: for securing data\n',
#  'pm',
#  'Sanap Aditya: are flaws bohot hai usme\n',
#  'pm',
#  'Teknath Jha: matlab\n',
#  'pm',
#  'Sanap Aditya: matlab agar koi node kharab ho gaya toh agli info block ho jati na\n',
#  'pm',
#  'Sanap Aditya: Usme loss hoga\n',
#  'pm',
#  'Teknath Jha: haa to vo to acchi baat hai and isiliye vo secure hai\n',
#  'pm',
#  'Sanap Aditya: are pr data loss ?\n',
#  'pm',
#  'Teknath Jha: ek mini project hai\n',
#  'pm',
#  'Sanap Aditya: Phir idea dhundni padegi\n',
#  'pm',
#  'Teknath Jha: nahi ho ga hum roken ge\n',
#  'pm',
#  'Teknath Jha: kyu\n',
#  'pm',
#  'Teknath Jha: ye idea accha nahi hai kya\n',
#  'pm',
#  'Sanap Aditya: Are implement kar payenge aisa kuch\n',
#  'pm',
#  'Sanap Aditya: direct company nahi dekhana chahiye re\n',
#  'pm',
#  'Sanap Aditya: thoda scale start me chota dekhte\n',
#  'pm',
#  'Teknath Jha: yahai hai sun to sab log call pe aao\n',
#  'pm',
#  'Teknath Jha: bata hu idea\n',
#  'pm',
#  'Teknath Jha: and ya easy hai ye\n',
#  'pm',
#  'Teknath Jha: .\n',
#  'pm',
#  'Teknath Jha: Domain fixed : block chain\n',
#  'pm',
#  'Teknath Jha: @919421243938   link bhej de   idea val\n',
#  'pm',
#  'Teknath Jha: abhi jo bol raha tha\n',
#  'pm',
#  'Teknath Jha: Daa ka aaj ka complexity vala question ka sol bhejo\n',
#  'pm',
#  'Sanap Aditya: +1\n',
#  'pm',
#  'Sanap Aditya: Question daal na\n',
#  'pm',
#  'Teknath Jha: Question to bhej\n',
#  'pm',
#  'Sanap Aditya: mereko nahi pata\n',
#  'pm',
#  'Sanap Aditya: t(n)=8* t(n/2) + b*n^2\n',
#  'pm',
#  'Sanap Aditya: isko back substitution se time complexity nikalana hai\n',
#  'pm',
#  'Teknath Jha: https://www.youtube.com/watch?v=1K9ebQJosvo\n',
#  'pm',
#  'Sanap Aditya: ans kya aaya\n',
#  'pm',
#  'Teknath Jha: Kar raha hu\n',
#  'pm',
#  'Teknath Jha: Base case kya hai\n',
#  'pm',
#  'Sanap Aditya: mtlab\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: woh +bn^2 hai\n',
#  'pm',
#  'Sanap Aditya: last ans wala tswir bhej\n',
#  'pm',
#  'Sanap Aditya: <Media omitted>\n',
#  'pm',
#  'Teknath Jha: 👍\n',
#  'pm',
#  'Sanap Aditya: <Media omitted>\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: https://trello.com/?utm_source=gdn&utm_medium=paid-display&utm_campaign=P:trello|O:ppm|V:gdn|G:in|L:en|F:aware|T:interest|Z:paid-display-fy21|I:exp-vac-youtube|A:video|D:desktop&utm_content=P:trello|O:ppm|V:gdn|G:in|L:en|F:aware|T:interest|Z:paid-display-fy21|I:exp-vac-youtube|A:video|D:desktop|U:interest_collaboration-try-free&dcm_source=2540927&dcm_medium=302450314&dcm_content=147994607&dcm_campaign=24888499&gclid=Cj0KCQjwssyJBhDXARIsAK98ITRcCU5lCc4aT1Tk5bh5Dy5c914QoB9LAYHqjj6b3rmjEmt2_E0jX4UaAsCQEALw_wcB\n',
#  'pm',
#  'Sanap Aditya: Bhai apne wala idea\n',
#  'pm',
#  'Sanap Aditya: implemented\n',
#  'pm',
#  'Sanap Aditya: kisine kiya kya week 3\n',
#  'pm',
#  'Sanap Aditya: DAA ka\n',
#  'pm',
#  'Sanap Aditya: aao re\n',
#  'pm',
#  'Avinash: Kal morning mai baat krte hai\n',
#  'pm',
#  'Teknath Jha: 👍\n',
#  'am',
#  'Avinash: Abhi time hai kya\n',
#  'am',
#  'Avinash: Sbko\n',
#  'am',
#  'Sanap Aditya: ha\n',
#  'am',
#  'Avinash: teknath??\n',
#  'am',
#  'Avinash: .\n',
#  'am',
#  'Sanap Aditya: teknath ????\n',
#  'am',
#  'Avinash: are aa bhai\n',
#  'am',
#  'Avinash: tera daa baad me kar\n',
#  'am',
#  'Teknath Jha: ok 3:30 ke baaad\n',
#  'am',
#  'Sanap Aditya: aa na abhi\n',
#  'am',
#  'Avinash: thik\n',
#  'am',
#  'Avinash: hai\n',
#  'pm',
#  'Teknath Jha: .\n',
#  'pm',
#  'Teknath Jha: .\n',
#  'pm',
#  'Sanap Aditya: andar lo na\n',
#  'pm',
#  'Teknath Jha: Nai bhi bahar hu\n',
#  'pm',
#  'Teknath Jha: Only Avinash can\n',
#  'pm',
#  'Sanap Aditya: ok\n',
#  'pm',
#  'Teknath Jha: kaha hai\n',
#  'pm',
#  'Sanap Aditya: call kr na usko\n',
#  'pm',
#  'Teknath Jha: K\n',
#  'pm',
#  'Teknath Jha: meet.google.com/yvt-invt-jro\n',
#  'pm',
#  'Avinash: You deleted this message\n',
#  'pm',
#  'Avinash: Join\n',
#  'pm',
#  'Teknath Jha: To join the meeting on Google Meet, click this link: \nhttps://meet.google.com/xsy-ikjf-mqi \n \nOr open Meet and enter this code: xsy-ikjf-mqi\n',
#  'pm',
#  'Teknath Jha: @919421243938\n',
#  'pm',
#  'Teknath Jha: aao re sab time nahi hai\n',
#  'pm',
#  'Teknath Jha: meet.google.com/grf-wzqf-npg\n',
#  'pm',
#  'Teknath Jha: iss pe\n',
#  'pm',
#  'Avinash: Ok\n',
#  'pm',
#  'Teknath Jha: @919421243938\n',
#  'pm',
#  'Teknath Jha: aa na\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: are 5 min\n',
#  'pm',
#  'Sanap Aditya: DAA ka 5 min\n',
#  'pm',
#  'Avinash: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: tum bolo tab tak\n',
#  'pm',
#  'Teknath Jha: @917219578500\n',
#  'pm',
#  'Teknath Jha: kaha hai re\n',
#  'pm',
#  'Sanap Aditya: le andar\n',
#  'pm',
#  'Teknath Jha: This message was deleted\n',
#  'pm',
#  'Teknath Jha: Dear Sir,\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 we are from TY-CSE\xa0 T3 Team 11\xa0 \xa0, and want to present our\xa0 ideation regarding mini project 1.DOMAIN\xa0 :\xa0 BLOCKCHAINAs\xa0 we have identified the major problems in examinations like (JEE,NEET,AIPMT,.etc)of\xa0 "PAPER\xa0 LEAKED " and this happens\xa0 mostly in all states ,\xa0 due to\xa0 providing authority to\xa0 wrong people which we as a human cannot distinguish\xa0 .But if we maintain this in a secure network\xa0 like BLOCKCHAIN then these wrong practices would stop.\nplease\xa0 suggest your views\xa0on this so that we can proceed furtherThankyou sir,\nyours sincerely\n2019BTECS000332019BTECS000111\n2019BTECS00077\n',
#  'pm',
#  'Avinash: sir ko daal\n',
#  'pm',
#  'Avinash: ki sir we have send you a one email\n',
#  'pm',
#  'Avinash: please check out  and let us know\n',
#  'pm',
#  'Teknath Jha: https://www.youtube.com/watch?v=pCgYFkyrHu4\n',
#  'pm',
#  'Teknath Jha: https://github.com/lexvanderstoep/medicalBlockchain\n',
#  'pm',
#  'Sanap Aditya: are kal mai sangli ja raha hoo\n',
#  'pm',
#  'Sanap Aditya: to udhar 10-10.30 baje pahchunga\n',
#  'pm',
#  'Avinash: @919323451278 sir ka message aya kya kuch\n',
#  'pm',
#  'Avinash: https://wcewlug.medium.com/blockchain-56e223a5a055\n',
#  'pm',
#  'Avinash: reference\n',
#  'pm',
#  'Sanap Aditya: are LA kadhi a aapli\n',
#  'pm',
#  'Avinash: parva\n',
#  'pm',
#  'Sanap Aditya: kitila\n',
#  'pm',
#  'Sanap Aditya: .\n',
#  'pm',
#  'Avinash: 3:30 nntar asel bahutek\n',
#  'pm',
#  'Sanap Aditya: nakkki ka\n',
#  'pm',
#  'Sanap Aditya: aapli PL3 chi kadhi a\n',
#  'pm',
#  'Avinash: mahiti nahi pn time table nusar\n',
#  'pm',
#  'Sanap Aditya: oral\n',
#  'pm',
#  'Sanap Aditya: ?\n',
#  'pm',
#  'Avinash: wednesday\n',
#  'pm',
#  'Sanap Aditya: kadhi\n',
#  'pm',
#  'Avinash: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: ahe re\n',
#  'pm',
#  'Sanap Aditya: MP1 10.15 la ahe\n',
#  'am',
#  'Teknath Jha: Nahi\n',
#  'pm',
#  'Sanap Aditya: are ek bar check karo na ki apna MP ka LA kab hai\n',
#  'pm',
#  'Teknath Jha: time table ?\n',
#  'pm',
#  'Sanap Aditya: MP1 or MP2\n',
#  'pm',
#  'Teknath Jha: MP 1\n',
#  'pm',
#  'Teknath Jha: ka LA 1\n',
#  'pm',
#  'Teknath Jha: 2019BTECS00033\n2019BTECS000111\n2019BTECS00077\n',
#  'pm',
#  'Teknath Jha: have u noticed something\n',
#  'pm',
#  'Sanap Aditya: yes\n',
#  'pm',
#  'Sanap Aditya: the roll no\n',
#  'pm',
#  'Sanap Aditya: time 10.15 na\n',
#  'pm',
#  'Teknath Jha: haa\n',
#  'pm',
#  'Sanap Aditya: are mai tb train mai hunga\n',
#  'pm',
#  'Teknath Jha: kab tak train me rahe ga\n',
#  'pm',
#  'Sanap Aditya: 10.30\n',
#  'pm',
#  'Teknath Jha: ok\n',
#  'pm',
#  'Teknath Jha: hojae gaa\n',
#  'pm',
#  'Sanap Aditya: to sir ko batana padega\n',
#  'pm',
#  'Teknath Jha: 11:30 tak humara aaega\n',
#  'pm',
#  'Sanap Aditya: Ok\n',
#  'pm',
#  'Sanap Aditya: phir thik hai\n',
#  'pm',
#  'Teknath Jha: no reply from sir\n',
#  'pm',
#  'Sanap Aditya: kaise re pt\n',
#  'pm',
#  'Sanap Aditya: thik hai\n',
#  'pm',
#  'Teknath Jha: what to do now?\n',
#  'pm',
#  'Sanap Aditya: apna 11.30 kaise\n',
#  'pm',
#  'Teknath Jha: team 11 hainaa\n',
#  'pm',
#  'Sanap Aditya: apne ko kaun hai\n',
#  'pm',
#  'Sanap Aditya: surve na\n',
#  'pm',
#  'Sanap Aditya: aur t2 ko ?\n',
#  'pm',
#  'Avinash: Team 1 hai thik se dekkho\n',
#  'pm',
#  'Avinash: Sir ke batch mai apna 1st naam hai\n',
#  'pm',
#  'Sanap Aditya: kya\n',
#  'pm',
#  'Sanap Aditya: wohi\n',
#  'pm',
#  'Sanap Aditya: I am calling to sir\n',
#  'pm',
#  'Sanap Aditya: to sir ko mail ka bhi batata\n',
#  'pm',
#  'Sanap Aditya: sir call nahi utha rahe\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: teknath try to message him on whatsapp\n',
#  'pm',
#  'Sanap Aditya: asap\n',
#  'pm',
#  'Teknath Jha: Did\n',
#  'pm',
#  'Avinash: What is the next message\n',
#  'pm',
#  'Teknath Jha: No reply from sir aaditya\n',
#  'pm',
#  'Teknath Jha: Aage ka photo bhej\n',
#  'pm',
#  'Avinash: Ya\n',
#  'pm',
#  'Avinash: Rejected..🤪\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Teknath Jha: @919421243938\n',
#  'pm',
#  'Sanap Aditya: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: TU sir ko msg kr\n',
#  'pm',
#  'Sanap Aditya: aur yaad dila ki bheja hai\n',
#  'pm',
#  'Teknath Jha: Kiyare\n',
#  'pm',
#  'Sanap Aditya: Ok\n',
#  'pm',
#  'Sanap Aditya: dekha kya\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: Are woh doc banani hai na\n',
#  'pm',
#  'Sanap Aditya: kal ke liye\n',
#  'pm',
#  'Teknath Jha: Haa idea to accept hojae\n',
#  'pm',
#  'Sanap Aditya: hona chahiye\n',
#  'pm',
#  'Avinash: https://youtu.be/qKsu3-Jkas0 reference\n',
#  'pm',
#  'Sanap Aditya: kiska\n',
#  'pm',
#  'Avinash: apne related hi hai dekh le\n',
#  'pm',
#  'Avinash: just for reference idea ane ke liye\n',
#  'pm',
#  'Teknath Jha: https://meet.google.com/htj-ipio-qnz\n',
#  'pm',
#  'Teknath Jha: sab join karo\n',
#  'pm',
#  'Teknath Jha: @917219578500  soya hai\n',
#  'pm',
#  'Sanap Aditya: OK\n',
#  'pm',
#  'Teknath Jha: call kar na avi ko\n',
#  'pm',
#  'Sanap Aditya: switch off\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: tu aa\n',
#  'pm',
#  'Sanap Aditya: shahid kapoor\n',
#  'pm',
#  'Teknath Jha: aaya\n',
#  'pm',
#  'Sanap Aditya: meko le\n',
#  'pm',
#  'Avinash: Are dusre gao aya charging kelyie\n',
#  'pm',
#  'Avinash: Heavy barrish🔥🔥\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: doc walale\n',
#  'pm',
#  'Sanap Aditya: bhai\n',
#  'pm',
#  'Sanap Aditya: IOT kaha lega re\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Teknath Jha: Pranita Bhosale and Team \tWCE Document tracking and reporting system: Bills, Requisitions, Reports, Proposals.\n\nAny employee/student should get to know current status of document submitted to institute at their figure tips (mobile app/portal). Also statistical analysis and report has to be generated for administrators periodically\tSender will submit documents…ticket will be issued to him/her ( pprox.. time/days to get completed) Keep track.. Generate unique code(label/tag) … generate logs (date, time, person)… sender can check status ..also if issues are there then auto message/email has to be generated to concerned(sender)..after fulfilling query/issue the system should maintain record of it\nApp has to be made available through Play store to customers. \n\tWCE faculty/ Staff/ Students-\uf0e0 HoDs-\uf0e0 Office concerned Clerks \uf0e0  Finance Officer (if related to money) -\uf0e0 Registrar--\uf0e0  Accounts Officer--\uf0e0 Director\tResponsive web portal and mobile app, SMS & Email notifications/alerts, IoT (sensors, barcode, RFID, scanner, arduino etc), Cloud platform, docker/container, authentication, auto signs, Ticket granting system, access control\n',
#  'pm',
#  'Teknath Jha: //\n',
#  'pm',
#  'Teknath Jha: Pranita Bhosale and Team \tWCE Document tracking and reporting system: Bills, Requisitions, Reports, Proposals.\n\nAny employee/student should get to know current status of document submitted to institute at their figure tips (mobile app/portal). Also statistical analysis and report has to be generated for administrators periodically\tSender will submit documents…ticket will be issued to him/her ( pprox.. time/days to get completed) Keep track.. Generate unique code(label/tag) … generate logs (date, time, person)… sender can check status ..also if issues are there then auto message/email has to be generated to concerned(sender)..after fulfilling query/issue the system should maintain record of it\nApp has to be made available through Play store to customers. \n\tWCE faculty/ Staff/ Students-\uf0e0 HoDs-\uf0e0 Office concerned Clerks \uf0e0  Finance Officer (if related to money) -\uf0e0 Registrar--\uf0e0  Accounts Officer--\uf0e0 Director\tResponsive web portal and mobile app, SMS & Email notifications/alerts, IoT (sensors, barcode, RFID, scanner, arduino etc), Cloud platform, docker/container, authentication, auto signs, Ticket granting system, access control\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Teknath Jha: https://www.gatevidyalay.com/travelling-salesman-problem-using-branch-and-bound-approach/\n',
#  'pm',
#  'Avinash: https://8worx.blogspot.com/2020/09/document-tracking-system-v-20.html\n',
#  'pm',
#  'Avinash: reference\n',
#  'pm',
#  'Teknath Jha: Abstract :\n',
#  'pm',
#  'Teknath Jha: Students have been facing problems in tracking their documents for \nverification at institute level and sometime they also missed deadlines\nof availing scholarships .\nWe develop a website "Doc Tracker" which will notify student to track their \ndocuments direct via our website, they will be notified via emails on each \nsuccessive stages of document .\nThis website will help  to short out the communication between authority and \nstudent . Student will not miss their scholarship.\nCollege staff will be able to direct contact to student to get work done.\n',
#  'pm',
#  'Teknath Jha: 😍\n',
#  'am',
#  'Teknath Jha: This message was deleted\n',
#  'am',
#  'Teknath Jha: baki complete karo  ye incomplete hai\n',
#  'am',
#  'Teknath Jha: <Media omitted>\n',
#  'am',
#  'Teknath Jha: Methodology and flowchart baki hai\n',
#  'am',
#  'Teknath Jha: flowchart add karde avi\n',
#  'am',
#  'Teknath Jha: methodology kisi ko pata haai to add kardo\n',
#  'pm',
#  'Sanap Aditya: methodology matlab agile jaisa na\n',
#  'pm',
#  'Teknath Jha: are huwa kya sab log free\n',
#  'pm',
#  'Teknath Jha: meet pe aao phir\n',
#  'pm',
#  'Teknath Jha: https://www.youtube.com/watch?v=gSQXq2_j-mw\n',
#  'pm',
#  'Teknath Jha: ?\n',
#  'pm',
#  'Sanap Aditya: ho gayi kya meet\n',
#  'pm',
#  'Teknath Jha: @917219578500    kidhar toi busy hai bha\n',
#  'pm',
#  'Sanap Aditya: okk\n',
#  'pm',
#  'Sanap Aditya: kya discuss karna hai\n',
#  'pm',
#  'Sanap Aditya: Karni kya meet\n',
#  'pm',
#  'Teknath Jha: haa\n',
#  'pm',
#  'Teknath Jha: avi linkl bheje ga tabhi\n',
#  'pm',
#  'Sanap Aditya: mai bheju kya\n',
#  'pm',
#  'Sanap Aditya: ruk\n',
#  'pm',
#  'Sanap Aditya: reply de\n',
#  'pm',
#  'Teknath Jha: vo bhi free hona chaiye nma sooooooooooooooooo\n',
#  'pm',
#  'Teknath Jha: link\n',
#  'pm',
#  'Sanap Aditya: 1 min\n',
#  'pm',
#  'Avinash: https://meet.google.com/tiv-djou-djs\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Teknath Jha: <Media omitted>\n',
#  'pm',
#  'Avinash: <Media omitted>\n',
#  'pm',
#  'Avinash: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: https://images.app.goo.gl/SiBZ6r9YJniTNbq89\n',
#  'pm',
#  'Avinash: https://ijisrt.com/wp-content/uploads/2017/06/Electronic-Document-Management-System-for-Higher-Education-Institution-1.pdf\n',
#  'am',
#  'Sanap Aditya: <Media omitted>\n',
#  'am',
#  'Sanap Aditya: Anything to add\n',
#  'am',
#  'Sanap Aditya: https://www.bezkoder.com/react-hooks-redux-login-registration-example/\n',
#  'am',
#  'Sanap Aditya: check it\n',
#  'am',
#  "Avinash: It's verifier not tracker\n",
#  'am',
#  'Avinash: 🙏👍\n',
#  'am',
#  'Sanap Aditya: Ky add karu ??\n',
#  'am',
#  'Avinash: Desk 1 , desk 2  aisa kuch karna hai kua\n',
#  'am',
#  'Avinash: Kya*\n',
#  'am',
#  'Avinash: ??\n',
#  'am',
#  'Avinash: If you want\n',
#  'am',
#  'Avinash: @919323451278 @919421243938 ??\n',
#  'am',
#  'Sanap Aditya: teknath la call krto ka\n',
#  'am',
#  'Sanap Aditya: Are woh access pe depend karega\n',
#  'am',
#  'Sanap Aditya: Administrator ne verify karne ke baad kisi aur ko verification dena hai kya\n',
#  'am',
#  'Avinash: Teknath ko puch ke dekh mujhe ye sirf verifier lga isliye\n',
#  'am',
#  'Sanap Aditya: OK\n',
#  'am',
#  'Teknath Jha: Yup\n',
#  'am',
#  'Teknath Jha: <Media omitted>\n',
#  'am',
#  'Sanap Aditya: are sun\n',
#  'am',
#  'Sanap Aditya: Loop jo hai woh reject se start karu ya delete doc se\n',
#  'am',
#  'Teknath Jha: Reject se\n',
#  'am',
#  'Sanap Aditya: Ok\n',
#  'am',
#  'Teknath Jha: Delete ka kuch nahi rakh\n',
#  'am',
#  'Sanap Aditya: OK\n',
#  'am',
#  'Teknath Jha: Vo privacy me hojae ga\n',
#  'am',
#  'Sanap Aditya: Pr aapn woh invalid doc bhi data base mai dalenge na\n',
#  'am',
#  'Sanap Aditya: toh woh delete karna hoga\n',
#  'am',
#  'Teknath Jha: Nahi uska rahede\n',
#  'am',
#  'Sanap Aditya: ye karu kya\n',
#  'am',
#  'Teknath Jha: Document student hai so vahi delete kare ga ya update kare ga\n',
#  'am',
#  'Teknath Jha: Nahi\n',
#  'am',
#  'Teknath Jha: 🛑\n',
#  'am',
#  'Sanap Aditya: are desk 2 ko rejection nahi denge na\n',
#  'am',
#  'Sanap Aditya: <Media omitted>\n',
#  'am',
#  'Sanap Aditya: DEkho re\n',
#  'am',
#  'Avinash: 👍\n',
#  'am',
#  'Sanap Aditya: koi changes\n',
#  'am',
#  'Avinash: Nhi nhi\n',
#  'am',
#  'Sanap Aditya: 👍👍\n',
#  'am',
#  'Teknath Jha: <Media omitted>\n',
#  'am',
#  'Teknath Jha: <Media omitted>\n',
#  'am',
#  'Sanap Aditya: 👍👍\n',
#  'pm',
#  'Teknath Jha: https://cses.fi/problemset/task/1682/\n',
#  'pm',
#  'Teknath Jha: kisi ko aata hai kya ye  ?\n',
#  'pm',
#  'Avinash: just check whether there any node which has 0 outgoing edge or o incoming edge then not possible\n',
#  'pm',
#  'Sanap Aditya: 👍👍👍\n',
#  'pm',
#  'Sanap Aditya: MEthodology hui kya\n',
#  'pm',
#  'Avinash: kr raha hu\n',
#  'pm',
#  'Sanap Aditya: <Media omitted>\n',
#  'pm',
#  'Sanap Aditya: <Media omitted>\n',
#  'pm',
#  "Teknath Jha: I did but there's something more  requirements failed  connection we've to print\n",
#  'pm',
#  'Avinash: You deleted this message\n',
#  'pm',
#  'Avinash: You deleted this message\n',
#  'pm',
#  "Avinash: and also one more condition if there is cycle present then also won't possible\n",
#  'pm',
#  'Avinash: cycle with no of nodes less than all nodes\n',
#  'am',
#  'Avinash: <Media omitted>\n',
#  'am',
#  'Teknath Jha: send in  downloadable format\n',
#  'am',
#  'Avinash: <Media omitted>\n',
#  'am',
#  'Avinash: is it ok ??\n',
#  'am',
#  'Avinash: please send here the updated ppt\n',
#  'am',
#  'Teknath Jha: <Media omitted>\n',
#  'am',
#  'Avinash: yai dala kya\n',
#  'am',
#  'Avinash: usme\n',
#  'am',
#  'Teknath Jha: plz add your work in respective  page\n',
#  'am',
#  'Teknath Jha: nope\n',
#  'am',
#  'Teknath Jha: its hard to extract .drawio file\n',
#  'am',
#  'Avinash: <Media omitted>\n',
#  'am',
#  'Avinash: done from my side my part\n',
#  'am',
#  'Teknath Jha: send  here finnal one from @919421243938\n',
#  'am',
#  'Sanap Aditya: Ky paathavu\n',
#  'am',
#  'Teknath Jha: merge  you  image into this ppt\n',
#  'am',
#  'Sanap Aditya: So image merge karu na\n',
#  'am',
#  'Teknath Jha: your*\n',
#  'am',
#  'Sanap Aditya: Ohh\n',
#  'am',
#  'Teknath Jha: <Media omitted>\n',
#  'am',
#  'Sanap Aditya: are woh vertical fit nahi ho rahi\n',
#  'am',
#  'Sanap Aditya: Ye page ka layout change nahi karna kya\n',
#  'am',
#  'Avinash: download in png format and try again\n',
#  'am',
#  'Sanap Aditya: .\n',
#  'am',
#  'Avinash: <Media omitted>\n',
#  'am',
#  'Sanap Aditya: aisa hai\n',
#  'am',
#  'Sanap Aditya: <Media omitted>\n',
#  'am',
#  'Avinash: like this\n',
#  'am',
#  'Avinash: 👍\n',
#  'am',
#  'Avinash: reduce flow chart title size\n',
#  'am',
#  'Sanap Aditya: OK\n',
#  'am',
#  'Sanap Aditya: But it is fixed na\n',
#  'am',
#  'Sanap Aditya: matlab woh specify kiya hai\n',
#  'am',
#  'Sanap Aditya: font and size\n',
#  'am',
#  'Avinash: just delete the instructions and resize\n',
#  'am',
#  'Sanap Aditya: Aur jo diagrams ke liye font size hai uska kya\n',
#  'am',
#  'Sanap Aditya: woh to image mai reduce ho gaya na\n',
#  'am',
#  'Avinash: janede jo sahi lage vo kr flowachart ko kabhi size,alignment  rahta kya\n',
#  'am',
#  'Avinash: unhone copy paste kiya hai\n',
#  'am',
#  'Avinash: dekha nahi khuch\n',
#  'am',
#  'Sanap Aditya: Ok\n',
#  'am',
#  'Sanap Aditya: <Media omitted>\n',
#  'am',
#  'Sanap Aditya: Dekho re\n',
#  'am',
#  'Sanap Aditya: Avinash tu pn image merge keliy na\n',
#  ...]

# %%
dates = re.findall(pattern, data)
dates
# Out:
# ['pm',
#  'am',
#  'am',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'am',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'am',
#  'am',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'am',
#  'am',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  'pm',
#  ...]

# %%
def preprocess(data):
    pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

    messages = re.split(pattern, data)[1:]
    dates = re.findall(pattern, data)

    df = pd.DataFrame({'user_message': messages, 'message_date': dates})
    # convert message_date type
    df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%Y, %H:%M - ')

    df.rename(columns={'message_date': 'date'}, inplace=True)

    users = []
    messages = []
    for message in df['user_message']:
        entry = re.split('([\w\W]+?):\s', message)
        if entry[1:]:  # user name
            users.append(entry[1])
            messages.append(" ".join(entry[2:]))
        else:
            users.append('group_notification')
            messages.append(entry[0])

    df['user'] = users
    df['message'] = messages
    df.drop(columns=['user_message'], inplace=True)

    df['only_date'] = df['date'].dt.date
    df['year'] = df['date'].dt.year
    df['month_num'] = df['date'].dt.month
    df['month'] = df['date'].dt.month_name()
    df['day'] = df['date'].dt.day
    df['day_name'] = df['date'].dt.day_name()
    df['hour'] = df['date'].dt.hour
    df['minute'] = df['date'].dt.minute

    period = []
    for hour in df[['day_name', 'hour']]['hour']:
        if hour == 23:
            period.append(str(hour) + "-" + str('00'))
        elif hour == 0:
            period.append(str('00') + "-" + str(hour + 1))
        else:
            period.append(str(hour) + "-" + str(hour + 1))

    df['period'] = period

    return df
